# %%
# instalar conda install requests lxml autopep8

# %%
MAIN_URL = 'https://www.computrabajo.com.co/ofertas-de-trabajo/?by=publicationtime&pubdate=1&sal=5'
SLICE_URL = 'https://www.computrabajo.com.co'
XPATH_link = '//div[@class="gO"]/div//h2/a/@href'
XPATH_name = '//div[@class="gO"]/div//h2/a/text()'
XPATH_city = '//div[@class="gO"]/div//div//span[@itemprop="addressLocality"]/a/text()'
XPATH_city2 = '//div[@class="gO"]/div//div//span[@itemprop="addressRegion"]/a/text()'
XPATH_summary = '//div[@class="gO"]/div//p/text()'
XPATH_company = '//div[@class="gO"]/div//div//span[@itemprop="name"]'
XPATH_company2 = '//div[@class="gO"]/div//div//span[@itemprop="name"]/a/text()'
XPATH_next_pag = '//div[@class="paginas paginasCenter"]//li[@class="siguiente"]/a/@href'
MAIN = 'Computrabajo'

# %%
import requests
import lxml.html as html
import pandas as pd
from datetime import datetime

def company_extract(first, second):
    companies = []
    j = 0
    for i in first:
        company = i.xpath('text()')[0].replace('\r','').replace('\n','').strip()
        
        if company:
            companies.append(company.strip())
        else:
            companies.append(second[j])
            j += 1
    return companies


def parse_home():
    try:
        response = requests.get(MAIN_URL)
        if response.status_code == 200:
            home = response.content.decode('utf-8')
            parsed = html.fromstring(home)
            extract_data(parsed)
        else:
            raise ValueError(f'Error: {response.status_code}')
    except ValueError as ve:
        print(ve)

def run():
    data = parse_home()
    return data

if __name__ == '__main__':
    data = run()
    print(data)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-104-e71c08e32475> in <module>
#      35
#      36 if __name__ == '__main__':
# ---> 37     data = run()
#      38     print(data)
#
# <ipython-input-104-e71c08e32475> in run()
#      31
#      32 def run():
# ---> 33     data = parse_home()
#      34     return data
#      35
#
# <ipython-input-104-e71c08e32475> in parse_home()
#      24             home = response.content.decode('utf-8')
#      25             parsed = html.fromstring(home)
# ---> 26             extract_data(parsed)
#      27         else:
#      28             raise ValueError(f'Error: {response.status_code}')
#
# <ipython-input-103-9451524c21e2> in extract_data(parsed)
#       6     city2 = parsed.xpath(XPATH_city2)
#       7     summary = parsed.xpath(XPATH_summary)
# ----> 8     company = company(parsed.xpath(XPATH_company), parsed.xpath(XPATH_company2))
#       9     date = f'{datetime.today().day}/{datetime.today().month}/{datetime.today().year}'
#      10     source = MAIN
#
# UnboundLocalError: local variable 'company' referenced before assignment

# %%
data.xpath(XPATH_link)[0].get
# Out:
# <Element a at 0x7fdf1e5259a0>

# %%
response = requests.get(MAIN_URL)
home = response.content.decode('utf-8')
parsed = html.fromstring(home)

# %%
a = parsed.xpath(XPATH_city)

# %%
a[].xpath('text()')[0].replace('\r','').replace('\n','').strip()
# Out:
# ''

# %%
def extract_data(parsed):
    
    link = parsed.xpath(XPATH_link)
    link = [SLICE_URL + i for i in link]
    name = parsed.xpath(XPATH_name)
    city = parsed.xpath(XPATH_city)
    city2 = parsed.xpath(XPATH_city2)
    summary = parsed.xpath(XPATH_summary)
    company = company_extract(parsed.xpath(XPATH_company), parsed.xpath(XPATH_company2))
    date = [f'{datetime.today().day}/{datetime.today().month}/{datetime.today().year}' for _ in range(len(link))]
    source = [MAIN for _ in range(len(link))]
    vacantes = []
    for i in range(len(link)):
        vacantes.append([name[i], date[i], company[i], link[i], summary[i], source[i], city[i], city2[i]])
    return vacantes

datos = extract_data(parsed)

# %%
import pandas as pd
import numpy as np
pd.DataFrame(datos)
# Out:
#                                                     0         1  \
# 0   supervisores o coordinadores call center tecni...  2/2/2021
# 1    Analista de optimización  Manejo de data science  2/2/2021
# 2                             Coordinador de sistemas  2/2/2021
# 3    Application Jr. Bases de Datos, SQL, JAVA, HTML.  2/2/2021
# 4       Bilingual Trainer (English) BPO / Call Center  2/2/2021
# 5      Analista Profesional CX y costumer Journey Map  2/2/2021
# 6                               Director  Call Center  2/2/2021
# 7                                      Jefe Workforce  2/2/2021
# 8   Antropología Sociólogo con Enfoque en el Consu...  2/2/2021
# 9   Asesor comercial Externo Banco excelentes Comi...  2/2/2021
# 10                      Director de Marketing Digital  2/2/2021
# 11                     Coordinador Logistico Bilingue  2/2/2021
# 12  Analista de optimización  Manejo de data scien...  2/2/2021
# 13                                         Gestor SQL  2/2/2021
# 14                       Director de mercadeo digital  2/2/2021
# 15          Analista de calidad indemnización de soat  2/2/2021
# 16                                    Agente bilingue  2/2/2021
# 17          Supervisor de calidad sector de alimentos  2/2/2021
# 18                                         Supervisor  2/2/2021
# 19                                 Senior Team Leader  2/2/2021
#
#                                 2  \
# 0   Importante empresa del sector
# 1                   ACTIVOS S A S
# 2                    TEMPO S.A.S.
# 3       Teleperformance Colombia
# 4       Teleperformance Colombia
# 5   Importante empresa del sector
# 6         VENTAS Y SERVICIOS S.A.
# 7         VENTAS Y SERVICIOS S.A.
# 8         VENTAS Y SERVICIOS S.A.
# 9                   ACTIVOS S A S
# 10                        navissi
# 11      Gestión Profesional S.A.S
# 12                  ACTIVOS S A S
# 13  Importante empresa del sector
# 14                   TEMPO S.A.S.
# 15  Importante empresa del sector
# 16     MANPOWER PROFESSIONAL LTDA
# 17                       Eficacia
# 18         Soluciones Inmediatas
# 19     MANPOWER PROFESSIONAL LTDA
#
#                                                     3  \
# 0   https://www.computrabajo.com.co/ofertas-de-tra...
# 1   https://www.computrabajo.com.co/ofertas-de-tra...
# 2   https://www.computrabajo.com.co/ofertas-de-tra...
# 3   https://www.computrabajo.com.co/ofertas-de-tra...
# 4   https://www.computrabajo.com.co/ofertas-de-tra...
# 5   https://www.computrabajo.com.co/ofertas-de-tra...
# 6   https://www.computrabajo.com.co/ofertas-de-tra...
# 7   https://www.computrabajo.com.co/ofertas-de-tra...
# 8   https://www.computrabajo.com.co/ofertas-de-tra...
# 9   https://www.computrabajo.com.co/ofertas-de-tra...
# 10  https://www.computrabajo.com.co/ofertas-de-tra...
# 11  https://www.computrabajo.com.co/ofertas-de-tra...
# 12  https://www.computrabajo.com.co/ofertas-de-tra...
# 13  https://www.computrabajo.com.co/ofertas-de-tra...
# 14  https://www.computrabajo.com.co/ofertas-de-tra...
# 15  https://www.computrabajo.com.co/ofertas-de-tra...
# 16  https://www.computrabajo.com.co/ofertas-de-tra...
# 17  https://www.computrabajo.com.co/ofertas-de-tra...
# 18  https://www.computrabajo.com.co/ofertas-de-tra...
# 19  https://www.computrabajo.com.co/ofertas-de-tra...
#
#                                                     4             5  \
# 0   ¡Esta oportunidad puede ser para ti! Important...  Computrabajo
# 1   Analista de estrategia de Transporte FORMACION...  Computrabajo
# 2   Empresa de productos para el hogar requiere pa...  Computrabajo
# 3   Multinacional de Contact Center se encuentra e...  Computrabajo
# 4   Reconocida multinacional se encuentra en búsqu...  Computrabajo
# 5   Profesional en Antropología, Sociología, Psico...  Computrabajo
# 6   Profesionales de preferencia con especializaci...  Computrabajo
# 7   Profesional o estudiante de últimos semestres ...  Computrabajo
# 8   Profesional en Antropología o Sociología, con ...  Computrabajo
# 9   Importante entidad se encuentra en la búsqueda...  Computrabajo
# 10  Profecional en administración, mercadeo o comu...  Computrabajo
# 11  Importante empresa del sector Logística requie...  Computrabajo
# 12  Analista de estrategia de Transporte FORMACION...  Computrabajo
# 13  Estudiante de carreras afines al cargo o cursa...  Computrabajo
# 14  Empresa de productos para el hogar requiere pa...  Computrabajo
# 15  ANALISTA DE CALIDAD INDEMNIZACIONES SOAT Enfer...  Computrabajo
# 16  Nos encontramos en busca de agentes bilingües ...  Computrabajo
# 17  Se requiere profesional en Ingeniería (Aliment...  Computrabajo
# 18  Empresa de telecomunicaciones requiere para nu...  Computrabajo
# 19  Importante empresa del sector se encuentra en ...  Computrabajo
#
#                6             7
# 0      Antioquia      Medellín
# 1   Cundinamarca         Funza
# 2      Atlántico  Barranquilla
# 3   Bogotá, D.C.  Bogotá, D.C.
# 4   Bogotá, D.C.  Bogotá, D.C.
# 5   Bogotá, D.C.  Bogotá, D.C.
# 6   Bogotá, D.C.  Bogotá, D.C.
# 7   Bogotá, D.C.  Bogotá, D.C.
# 8   Bogotá, D.C.  Bogotá, D.C.
# 9      Antioquia      Medellín
# 10     Antioquia      Medellín
# 11  Cundinamarca         Funza
# 12  Cundinamarca         Funza
# 13  Bogotá, D.C.  Bogotá, D.C.
# 14     Atlántico  Barranquilla
# 15  Bogotá, D.C.  Bogotá, D.C.
# 16  Bogotá, D.C.  Bogotá, D.C.
# 17  Bogotá, D.C.  Bogotá, D.C.
# 18  Bogotá, D.C.  Bogotá, D.C.
# 19     Atlántico  Barranquilla

# %%
np.array(datos).reshape(8, 20)
# Out:
# array([['supervisores o coordinadores call center tecnicos  tecnologos o profesionales contratación inmediata',
#         'Analista de optimización  Manejo de data science',
#         'Coordinador de sistemas',
#         'Application Jr. Bases de Datos, SQL, JAVA, HTML.',
#         'Bilingual Trainer (English) BPO / Call Center',
#         'Reconocida multinacional se encuentra en búsqueda de Trainer / Entrenador Bilngue (Inglés).  Funciones: •Realizar la...',
#         'Profesional en Antropología, Sociología, Psicologia del Consumidos o carreras a fines, con 2 años de Experiencia en...',
#         'Profesionales de preferencia con especialización con mínimo 3 años de experiencia en el cargos Director Call Center o...',
#         'Profesional o estudiante de últimos semestres con mínimo 2 años de experiencia en contact center, indicadores...',
#         'Profesional en Antropología o Sociología, con 2 años de Experiencia en segmentos, servicio al cliente, estrategia y...',
#         'Importante entidad se encuentra en la búsqueda de asesores externos de libranza o hipotecarios para el cargo de...',
#         'Profecional en administración, mercadeo o comunicación social Especialización en marketing Digital yredes  Excelente...',
#         'Importante empresa del sector Logística requiere para su equipo de trabajo, personas entre los 30 y 45 años para el...',
#         'Analista de estrategia de Transporte FORMACION Profesional en carreras administrativas o matemáticas, estadística etc....',
#         'Estudiante de carreras afines al cargo o cursando mínimo 5 semestre de carrera profesional, con mínimo 2 años de...',
#         'Empresa de productos para el hogar requiere para su vinculacion Profesional en Mercadeo. Con 3 a 4 años como director...',
#         'ANALISTA DE CALIDAD INDEMNIZACIONES SOAT Enfermera Jefe, Especialista en Auditoria y afines. Experiencia: Mínima...',
#         'Nos encontramos en busca de agentes bilingües para la mejor campaña de ventas de Bogotá. Si tienes nivel de inglés...',
#         'Se requiere profesional en Ingeniería (Alimentos, Ambiental o industrial) o ciencias (Microbiología o Bacteriología),...',
#         'Empresa de telecomunicaciones requiere para nuevo proyecto en Bogotá y alrededoresProfesional o Tecnólogos...',
#         'Importante empresa del sector se encuentra en búsqueda de Senior Team Leader bilingüe (inglés B2+/C1), en...'],
#        ['Computrabajo', 'Computrabajo', 'Computrabajo', 'Computrabajo',
#         'Computrabajo', 'Computrabajo', 'Computrabajo', 'Computrabajo',
#         'Computrabajo', 'Computrabajo', 'Computrabajo', 'Computrabajo',
#         'Computrabajo', 'Computrabajo', 'Computrabajo', 'Computrabajo',
#         'Computrabajo', 'Computrabajo', 'Computrabajo', 'Computrabajo'],
#        ['Antioquia', 'Cundinamarca', 'Atlántico', 'Bogotá, D.C.',
#         'Bogotá, D.C.', 'Bogotá, D.C.', 'Bogotá, D.C.', 'Bogotá, D.C.',
#         'Bogotá, D.C.', 'Antioquia', 'Antioquia', 'Cundinamarca',
#         'Cundinamarca', 'Bogotá, D.C.', 'Atlántico', 'Bogotá, D.C.',
#         'Bogotá, D.C.', 'Bogotá, D.C.', 'Bogotá, D.C.', 'Atlántico'],
#        ['Medellín', 'Funza', 'Barranquilla', 'Bogotá, D.C.',
#         'Bogotá, D.C.', 'Bogotá, D.C.', 'Bogotá, D.C.', 'Bogotá, D.C.',
#         'Bogotá, D.C.', 'Medellín', 'Medellín', 'Funza', 'Funza',
#         'Bogotá, D.C.', 'Barranquilla', 'Bogotá, D.C.', 'Bogotá, D.C.',
#         'Bogotá, D.C.', 'Bogotá, D.C.', 'Barranquilla']], dtype='<U231')

# %%
    np.array()
